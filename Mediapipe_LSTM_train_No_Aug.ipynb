# %% [markdown]
# # Khởi tạo liên kết Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Tải Mediapipe

# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.26)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.25.2)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.8.0.76)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 25.1 MB/s eta 0:00:00
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.7-py3-none-any.whl (32 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.3 which is incompatible.
# Successfully installed mediapipe-0.10.14 protobuf-4.25.3 sounddevice-0.4.7

# %% [markdown]
# # Các thư viện sử dụng

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
import cv2
import shutil
from PIL import Image
import time
import csv
import threading

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, SimpleRNN
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, GlobalMaxPool2D, MaxPooling2D
# from keras.layers import TimeDistributed, GRU, Dense, Dropout
from keras.layers import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
from keras.losses import categorical_crossentropy
# Import mediapipe
import mediapipe as mp
# from mediapipe.solutions.drawing_utils import mp_drawing
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
# Label encoder
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical


import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, SimpleRNN
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, GlobalMaxPool2D, MaxPooling2D
# from keras.layers import TimeDistributed, GRU, Dense, Dropout
from keras.layers import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, CSVLogger
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

# %% [markdown]
# # Định nghĩa các biến toàn cục

# %%
# Define parameters
selected_word = ["Do","Vang","Xanhla","Xanhduong","Hong"]
n_classes = len(selected_word)
# Frame sampling parameters
frames_per_video = 10
target_size = (1920, 1080)

# Dataset multiplier
number_of_augmentations = 10

# some global params
SIZE = (128, 128)

# SIZE = (224, 224)
CHANNELS = 3
NBFRAME = 10
BS = 20

NUM_THREADS = 8

#preprocessing
LENGTH_TRIM = 100
classes_file = '/content/drive/MyDrive/VietNam SignLanguage/classes.npy'

# %% [markdown]
# # Tiền xử lý dữ liệu

# %% [markdown]
# ## Các hàm phụ trợ

# %%
# resize image by dsize = (128, 128)
def resizeImage(img, dsize):
  sizeImg = (img.shape[0],img.shape[1])
  if sizeImg != dsize and dsize != (None, None):
    img = cv2.resize(img,dsize)
  return img

# remove left right background
def removeTrimBackground(img, length = 120):
  img = img[:,length:-1*length]
  return img

def resizeScale(img, scale = 30):
  scale_percent = scale # percent of original size
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)

  # resize image
  resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
  return resized

# %%
def preprocessingImg(img, dsize = (128,128)):
  # img = human_detection(img)
  img = removeTrimBackground(img, LENGTH_TRIM)
  img = resizeImage(img, dsize)
  return img

# %%
def readFramesThread(sema, x_data, y_data, word, path, dsize):
  sema.acquire()

  frames = os.listdir(path)
  lframes = []

  for frame in frames: # read all frames in video
    frame_path = os.path.join(path, frame)
    img = cv2.imread(frame_path, 1)
    img = preprocessingImg(img, dsize)
    lframes.append(img)

  x_data.append(lframes) # add video into list
  y_data.append(word) # add label

  # time.sleep(0.2)
  sema.release()


def readDataThread(input_path, csv_file, dsize=(128,128), listWord = None):
  x_data = []
  y_data = []

  maxthreads = NUM_THREADS
  sema = threading.Semaphore(value=maxthreads) # sema type
  threads = list()

  with open(csv_file) as csvfile: # read path from csv
    reader = csv.reader(csvfile)
    print(reader)
    for row in reader:
      # video path
      video = row[0]
      word = video.split('/')[0]

      if (listWord != None) and (word not in listWord): # decrease num classes
        continue

      # print(video)
      path = os.path.join(input_path, video)
      # execute thread
      thread = threading.Thread( target=readFramesThread, args=(sema, x_data, y_data, word, path, dsize) )
      threads.append(thread)
      thread.start()

    for t in threads: # for waiting all thread end
      t.join()

  return x_data, y_data

# %%
def readFrames(path, dsize):
  frames = os.listdir(path)
  lframes = []

  for frame in frames: # read all frames in video
    frame_path = os.path.join(path, frame)
    img = cv2.imread(frame_path, 1)
    img = resizeImage(img, dsize)
    lframes.append(img)

  return lframes

def readData(input_path, csv_file, dsize=(128,128), listWord = None):
  x_data = []
  y_data = []

  with open(csv_file) as csvfile: # read path from csv
    reader = csv.reader(csvfile)
    for row in reader:
      # video path
      video = row[0]
      word = video.split('/')[0]
      # if (listWord != None) and (word not in listWord): # decrease num classes
      #   continue

      print(video)
      path = os.path.join(input_path, video)
      lframes = readFrames(path, dsize)

      x_data.append(lframes) # add video into list
      y_data.append(word) # add label

  return x_data, y_data

# %%
#encoder label to train in model
def encoderLabel(y_train, y_test, classes_file = 'classes.npy', save = True):
  encoder = LabelEncoder()
  encoder.fit(y_train)

  # save classes, save as numpy array
  if save == True:
    np.save(classes_file, encoder.classes_)

  # encoder to number
  y_train1 = encoder.fit_transform(y_train)
  y_test1 = encoder.fit_transform(y_test)
  # [a,c, y,a ] -> [1,2,3,1]
  num_classes=len(np.unique(y_train))
  #encoder to binary matrix
  y_train2 = to_categorical(y_train1, num_classes=len(np.unique(y_train)))
  y_test2 = to_categorical(y_test1, num_classes=len(np.unique(y_test)))

  return y_train2, y_test2, num_classes

# %% [markdown]
# ## Đọc dữ liệu và chuẩn hóa dữ liệu

# %%
# prepare train data
start = time.time()

train_path = "/content/drive/MyDrive/VietNam SignLanguage/videoperfolder/train_dir"
train_csv = '/content/drive/MyDrive/VietNam SignLanguage/videoperfolder/train_dir_2.csv'

# x_train_o, y_train_o = readDataThread(train_path, train_csv, SIZE, listWord)
x_train_o, y_train_o = readDataThread(train_path, train_csv, SIZE)
end = time.time()
print('time:', end - start)
# Out:
# <_csv.reader object at 0x79f5045a09e0>
# time: 88.4888105392456

# %%
# prepare test data
start = time.time()

test_path = '/content/drive/MyDrive/VietNam SignLanguage/videoperfolder/val_dir'
test_csv = '/content/drive/MyDrive/VietNam SignLanguage/videoperfolder/val_2.csv'

# x_test_o, y_test_o = readDataThread(test_path, test_csv, SIZE, listWord)
x_test_o, y_test_o = readDataThread(test_path, test_csv, SIZE)

end = time.time()
print('time:', end - start)
# Out:
# <_csv.reader object at 0x79f5045a0b30>
# time: 25.883347272872925

# %% [markdown]
# # Triển khai MediaPipe

# %%
# Mediapipe holistic
mp_holistic = mp.solutions.holistic

def detect_landmarks(frame):
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5, static_image_mode=False) as holistic:
        results = holistic.process(frame_rgb)
    return results

# %%
# right hand
def get_coord_for_R_hand(results):
    x_coord_R_hand = []
    y_coord_R_hand = []
    z_coord_R_hand = []

    if results.right_hand_landmarks:
        #append coordinates
        for landmark in results.right_hand_landmarks.landmark:
            if landmark:
                x_coord_R_hand.append(landmark.x)
                y_coord_R_hand.append(landmark.y)
                z_coord_R_hand.append(landmark.z)
            else:
                x_coord_R_hand.append(0)
                y_coord_R_hand.append(0)
                z_coord_R_hand.append(0)
        print("✅ Right hand detected")

    else:
        for index in range(21):
            x_coord_R_hand.append(0)
            y_coord_R_hand.append(0)
            z_coord_R_hand.append(0)
        print("❌ Right hand not detected")

    return x_coord_R_hand, y_coord_R_hand, z_coord_R_hand

# %%
#left hand

def get_coord_for_L_hand(results):
    x_coord_L_hand = []
    y_coord_L_hand = []
    z_coord_L_hand = []

    if results.left_hand_landmarks:
        # Append coordinates
        for landmark in results.left_hand_landmarks.landmark:
            if landmark:
                x_coord_L_hand.append(landmark.x)
                y_coord_L_hand.append(landmark.y)
                z_coord_L_hand.append(landmark.z)
            else:
                x_coord_L_hand.append(0)
                y_coord_L_hand.append(0)
                z_coord_L_hand.append(0)
        print("✅ Left hand detected")
    else:
        # No left hand detected, populate with NaN values
        for index in range(21):
            x_coord_L_hand.append(0)
            y_coord_L_hand.append(0)
            z_coord_L_hand.append(0)
        print("❌ Left hand not detected")

    return x_coord_L_hand, y_coord_L_hand, z_coord_L_hand

# %%
# pose
def get_coord_for_pose(results):
    x_coord_pose = []
    y_coord_pose = []
    z_coord_pose = []

    if results.pose_landmarks:
        # loop over all landmarks for each hand
        for landmark in results.pose_landmarks.landmark:
            if landmark:
                x_coord_pose.append(landmark.x)
                y_coord_pose.append(landmark.y)
                z_coord_pose.append(landmark.z)
                # print(f"Landmark X: {landmark.x}, Y: {landmark.y}, Z: {landmark.z}")
            else:
                x_coord_pose.append(0)
                y_coord_pose.append(0)
                z_coord_pose.append(0)
        print("✅ Pose detected")

    else:
        x_coord_pose = [0] * 33
        y_coord_pose = [0] * 33
        z_coord_pose = [0] * 33
        print("❌ Pose not detected")

    x_coord_pose = x_coord_pose[0:25]
    y_coord_pose = y_coord_pose[0:25]
    z_coord_pose = z_coord_pose[0:25]

    return x_coord_pose, y_coord_pose, z_coord_pose

# %%
#normalize coordinates with respect to the nose
def get_norm_coord(x, y, z, results):
    x_coord_pose, y_coord_pose, z_coord_pose = get_coord_for_pose(results)

    x_norm = []
    y_norm = []
    z_norm = []

    for coord_x, coord_y, coord_z in zip(x, y, z):
        if all(coord == 0 for coord in (coord_x, coord_y, coord_z)):
            x_norm.append(0)
            y_norm.append(0)
            z_norm.append(0)
        else:
            x_norm.append((coord_x - x_coord_pose[0])/(abs(x_coord_pose[11]-x_coord_pose[12])))
            y_norm.append((coord_y - y_coord_pose[0])/(abs(x_coord_pose[11]-x_coord_pose[12])))
            z_norm.append((coord_z - z_coord_pose[0])/(abs(x_coord_pose[11]-x_coord_pose[12])))

    return x_norm, y_norm, z_norm

# %%
#daw the annoted image

def draw_(results, frame):
    annotated_image = frame.copy()

    if results.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=results.right_hand_landmarks,
            connections=mp_holistic.HAND_CONNECTIONS)
        print("✅ Right hand annotated")
    else:
        print("❌ Right hand not annotated")

    if results.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=results.left_hand_landmarks,
            connections=mp_holistic.HAND_CONNECTIONS)
        print("✅ Left hand annotated")
    else:
        print("❌ Left hand not annotated")


    if results.pose_landmarks:
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=results.pose_landmarks,
            connections=mp_holistic.POSE_CONNECTIONS)
        print("✅ Pose annotated")
    else:
        print("❌ Pose not annotated")

    return annotated_image

# %%
# get a series of coordinates for one frame
def coordinates_per_frame(results):
    x_coord_R_hand, y_coord_R_hand, z_coord_R_hand = get_coord_for_R_hand(results)
    x_coord_L_hand, y_coord_L_hand, z_coord_L_hand = get_coord_for_L_hand(results)
    x_coord_pose, y_coord_pose, z_coord_pose = get_coord_for_pose(results)

    X_frame = x_coord_R_hand + y_coord_R_hand + z_coord_R_hand + \
          x_coord_L_hand + y_coord_L_hand + z_coord_L_hand + \
          x_coord_pose + y_coord_pose + z_coord_pose
    return X_frame

# %%
# get a series of coordinates for one frame
def normalized_coordinates_per_frame(results):
    x_coord_R_hand, y_coord_R_hand, z_coord_R_hand = get_coord_for_R_hand(results)
    x_coord_L_hand, y_coord_L_hand, z_coord_L_hand = get_coord_for_L_hand(results)
    x_coord_pose, y_coord_pose, z_coord_pose = get_coord_for_pose(results)

    x_norm_coord_R_hand, y_norm_coord_R_hand, z_norm_coord_R_hand  = get_norm_coord(x_coord_R_hand, y_coord_R_hand, z_coord_R_hand, results)
    x_norm_coord_L_hand, y_norm_coord_L_hand, z_norm_coord_L_hand = get_norm_coord(x_coord_L_hand, y_coord_L_hand, z_coord_L_hand, results)
    x_norm_coord_pose, y_norm_coord_pose, z_norm_coord_pose = get_norm_coord(x_coord_pose, y_coord_pose, z_coord_pose, results)

    X_frame_norm = x_norm_coord_R_hand + y_norm_coord_R_hand + z_norm_coord_R_hand + \
          x_norm_coord_L_hand + y_norm_coord_L_hand + z_norm_coord_L_hand + \
          x_norm_coord_pose + y_norm_coord_pose + z_norm_coord_pose
    return X_frame_norm

# %%
frame = cv2.imread("/content/drive/MyDrive/VietNam SignLanguage/videoperfolder/test_dir/Do/Do_011_001.mp4/Do_011_001_frame_10.jpeg")
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame_rgb)
plt.show()

# %%
results = detect_landmarks(frame_rgb)
x_coord_R_hand, y_coord_R_hand, z_coord_R_hand = get_coord_for_R_hand(results)
x_coord_L_hand, y_coord_L_hand, z_coord_L_hand = get_coord_for_L_hand(results)
x_coord_pose, y_coord_pose, z_coord_pose = get_coord_for_pose(results)
# Out:
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# /usr/local/lib/python3.10/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
annotated_image = draw_(results, frame)
plt.imshow(annotated_image)
# Out:
# ✅ Right hand annotated
# ❌ Left hand not annotated
# ✅ Pose annotated

# %%
print(len(x_coord_R_hand))
print(len(y_coord_R_hand))
print(len(z_coord_R_hand))
print(len(x_coord_L_hand))
print(len(y_coord_L_hand))
print(len(z_coord_L_hand))
print(len(x_coord_pose))
print(len(y_coord_pose))
print(len(z_coord_pose))
# Out:
# 21
# 21
# 21
# 21
# 21
# 21
# 25
# 25
# 25

# %%
X_frame = normalized_coordinates_per_frame(results)
len(X_frame)
# Out:
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# 201

# %%
# Apply mediapipe for all frames
def mediapipe_video_to_coord(X):
    X_coord = []

    for video_count in range(len(X)):
        video = X[video_count]
        video_frames = []

        for frame_count in range(NBFRAME):
            frame = video[frame_count]
            results = detect_landmarks(frame)
            # X_frame = coordinates_per_frame(results)
            X_frame = normalized_coordinates_per_frame(results)
            video_frames.append(X_frame)

        X_coord.append(video_frames)

    X_coord = tf.convert_to_tensor(X_coord)
    return X_coord

# %%
# convert to numpy array
x_train = mediapipe_video_to_coord(np.array(x_train_o))
x_test = mediapipe_video_to_coord(np.array(x_test_o))
y_train = np.array(y_train_o)
y_test = np.array(y_test_o)
print('x_train shape', x_train.shape) # (400, 10, 128, 128, 3) max 2560
print('y_train shape', y_train.shape) # (400,)
print('x_test shape', x_test.shape) # (100, 10, 128, 128, 3) max 640
print('y_test shape', y_test.shape) # (100,)

convert = False
if convert == True:
  n, nb, h, w, c = x_train.shape
  x_train= x_train.reshape(n, nb, h*w*c)
  n, nb, h, w, c = x_test.shape
  x_test= x_test.reshape(n, nb, h*w*c)

  print('x_train shape', x_train.shape) # (400, 10, 223) max 2560
  print('y_train shape', y_train.shape) # (400,)
  print('x_test shape', x_test.shape) # (100, 10, 128, 128, 3) max 640
  print('y_test shape', y_test.shape) # (100,)
# Out:
# /usr/local/lib/python3.10/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ...
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ✅ Left hand detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ❌ Right hand not detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Right hand detected
# ❌ Left hand not detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# ✅ Pose detected
# x_train shape (200, 10, 201)
# y_train shape (200,)
# x_test shape (50, 10, 201)
# y_test shape (50,)

# %%
x_train = x_train /255.
x_test = x_test / 255.

# %% [markdown]
# # Mã hóa nhãn dữ liệu

# %%
listclasses =  np.unique(y_train)
num_classes = len(listclasses)
print(num_classes)
print(listclasses)

y_train_decode, y_test_decode, num_classes = encoderLabel(y_train, y_test)

print(y_train_decode.shape)
print(y_test_decode.shape)
# Out:
# 5
# ['Do' 'Hong' 'Vang' 'Xanh duong' 'Xanh la']
# (200, 5)
# (50, 5)

# %% [markdown]
# # Triển khai mô hình LSTM

# %%
dim = 201
def LSTMModel(dim):
    model = Sequential()
    model.add(LSTM(64,return_sequences=True, activation='relu', input_shape=(NBFRAME,dim)))
    model.add(LSTM(128,return_sequences=True, activation = 'relu'))
    model.add(LSTM(256,return_sequences=True,activation="relu"))
    model.add(LSTM(64, return_sequences = False,activation='relu'))
    model.add(Dense(64,activation='relu'))
    model.add(Dense(32,activation = 'relu'))
    model.add(Dense(5,activation='softmax'))
  # sgd = keras.optimizers.SGD( momentum=0.9, nesterov=True)
    model.compile(optimizer = 'Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])
    return model

# %%
model = LSTMModel(dim)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 64)            68096
#
#  lstm_1 (LSTM)               (None, 10, 128)           98816
#
#  lstm_2 (LSTM)               (None, 10, 256)           394240
#
#  lstm_3 (LSTM)               (None, 64)                82176
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 649733 (2.48 MB)
# Trainable params: 649733 (2.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tic = time.time()

EPOCHS = 100
early_stoping = EarlyStopping(monitor='val_accuracy', patience=9, verbose=1, mode='max')
history = model.fit(x_train, y_train_decode,
            epochs=EPOCHS,
            batch_size=BS,
            shuffle=True,
            validation_data = (x_test, y_test_decode),
            verbose=1,
           )

toc = time.time()
print("TRAINING TIME: ", toc-tic)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 9s 346ms/step - loss: 1.6109 - categorical_accuracy: 0.1550 - val_loss: 1.6095 - val_categorical_accuracy: 0.2000
# Epoch 2/100
# 10/10 [==============================] - 2s 155ms/step - loss: 1.6098 - categorical_accuracy: 0.2000 - val_loss: 1.6094 - val_categorical_accuracy: 0.2000
# Epoch 3/100
# 10/10 [==============================] - 1s 83ms/step - loss: 1.6096 - categorical_accuracy: 0.2000 - val_loss: 1.6094 - val_categorical_accuracy: 0.2000
# Epoch 4/100
# 10/10 [==============================] - 1s 91ms/step - loss: 1.6096 - categorical_accuracy: 0.2000 - val_loss: 1.6092 - val_categorical_accuracy: 0.2000
# Epoch 5/100
# 10/10 [==============================] - 1s 87ms/step - loss: 1.6091 - categorical_accuracy: 0.2700 - val_loss: 1.6083 - val_categorical_accuracy: 0.2400
# Epoch 6/100
# 10/10 [==============================] - 1s 84ms/step - loss: 1.6061 - categorical_accuracy: 0.2050 - val_loss: 1.5978 - val_categorical_accuracy: 0.2800
# Epoch 7/100
# 10/10 [==============================] - 1s 88ms/step - loss: 1.5608 - categorical_accuracy: 0.3000 - val_loss: 1.4312 - val_categorical_accuracy: 0.3600
# Epoch 8/100
# 10/10 [==============================] - 1s 152ms/step - loss: 1.5006 - categorical_accuracy: 0.3600 - val_loss: 1.5540 - val_categorical_accuracy: 0.2200
# Epoch 9/100
# 10/10 [==============================] - 2s 160ms/step - loss: 1.5455 - categorical_accuracy: 0.2000 - val_loss: 1.4693 - val_categorical_accuracy: 0.2600
# Epoch 10/100
# 10/10 [==============================] - 1s 128ms/step - loss: 1.3035 - categorical_accuracy: 0.3300 - val_loss: 1.2699 - val_categorical_accuracy: 0.3400
# Epoch 11/100
# 10/10 [==============================] - 1s 134ms/step - loss: 1.1244 - categorical_accuracy: 0.3800 - val_loss: 1.0934 - val_categorical_accuracy: 0.4400
# Epoch 12/100
# 10/10 [==============================] - 1s 129ms/step - loss: 1.0173 - categorical_accuracy: 0.4350 - val_loss: 1.0347 - val_categorical_accuracy: 0.4000
# Epoch 13/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.9777 - categorical_accuracy: 0.4700 - val_loss: 1.0134 - val_categorical_accuracy: 0.4800
# Epoch 14/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.9645 - categorical_accuracy: 0.4750 - val_loss: 0.9576 - val_categorical_accuracy: 0.5400
# Epoch 15/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.9411 - categorical_accuracy: 0.5200 - val_loss: 0.9415 - val_categorical_accuracy: 0.5400
# Epoch 16/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.8786 - categorical_accuracy: 0.4950 - val_loss: 0.9042 - val_categorical_accuracy: 0.5200
# Epoch 17/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.8628 - categorical_accuracy: 0.5000 - val_loss: 0.8165 - val_categorical_accuracy: 0.5200
# Epoch 18/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.8610 - categorical_accuracy: 0.5150 - val_loss: 0.9177 - val_categorical_accuracy: 0.5400
# Epoch 19/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8773 - categorical_accuracy: 0.5150 - val_loss: 0.8463 - val_categorical_accuracy: 0.5600
# Epoch 20/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.8537 - categorical_accuracy: 0.6050 - val_loss: 0.8851 - val_categorical_accuracy: 0.5800
# Epoch 21/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.7845 - categorical_accuracy: 0.6150 - val_loss: 0.8792 - val_categorical_accuracy: 0.6400
# Epoch 22/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.7705 - categorical_accuracy: 0.6700 - val_loss: 0.8524 - val_categorical_accuracy: 0.6200
# Epoch 23/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.7198 - categorical_accuracy: 0.6900 - val_loss: 0.7473 - val_categorical_accuracy: 0.6200
# Epoch 24/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.7087 - categorical_accuracy: 0.6750 - val_loss: 0.7806 - val_categorical_accuracy: 0.6200
# Epoch 25/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.7172 - categorical_accuracy: 0.6550 - val_loss: 0.6827 - val_categorical_accuracy: 0.6000
# Epoch 26/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.6324 - categorical_accuracy: 0.6450 - val_loss: 0.6736 - val_categorical_accuracy: 0.6600
# Epoch 27/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.6215 - categorical_accuracy: 0.7250 - val_loss: 0.7835 - val_categorical_accuracy: 0.6400
# Epoch 28/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.6130 - categorical_accuracy: 0.7400 - val_loss: 0.6873 - val_categorical_accuracy: 0.7400
# Epoch 29/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5807 - categorical_accuracy: 0.6600 - val_loss: 0.7025 - val_categorical_accuracy: 0.6800
# Epoch 30/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.5841 - categorical_accuracy: 0.7400 - val_loss: 0.6809 - val_categorical_accuracy: 0.6600
# Epoch 31/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.6345 - categorical_accuracy: 0.7000 - val_loss: 0.8320 - val_categorical_accuracy: 0.6800
# Epoch 32/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.5741 - categorical_accuracy: 0.7050 - val_loss: 0.8003 - val_categorical_accuracy: 0.6600
# Epoch 33/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.5369 - categorical_accuracy: 0.7300 - val_loss: 0.7257 - val_categorical_accuracy: 0.7400
# Epoch 34/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4935 - categorical_accuracy: 0.7800 - val_loss: 0.7096 - val_categorical_accuracy: 0.7000
# Epoch 35/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.4445 - categorical_accuracy: 0.7900 - val_loss: 0.8139 - val_categorical_accuracy: 0.7800
# Epoch 36/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.5205 - categorical_accuracy: 0.7100 - val_loss: 0.6173 - val_categorical_accuracy: 0.7400
# Epoch 37/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.4483 - categorical_accuracy: 0.8150 - val_loss: 0.7675 - val_categorical_accuracy: 0.7400
# Epoch 38/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4166 - categorical_accuracy: 0.7700 - val_loss: 0.6580 - val_categorical_accuracy: 0.7800
# Epoch 39/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4009 - categorical_accuracy: 0.7850 - val_loss: 0.8902 - val_categorical_accuracy: 0.7800
# Epoch 40/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4026 - categorical_accuracy: 0.8050 - val_loss: 0.9977 - val_categorical_accuracy: 0.7400
# Epoch 41/100
# 10/10 [==============================] - 1s 68ms/step - loss: 0.5229 - categorical_accuracy: 0.7350 - val_loss: 0.6132 - val_categorical_accuracy: 0.7600
# Epoch 42/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4895 - categorical_accuracy: 0.7950 - val_loss: 0.6972 - val_categorical_accuracy: 0.7200
# Epoch 43/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.4790 - categorical_accuracy: 0.7800 - val_loss: 0.7839 - val_categorical_accuracy: 0.7000
# Epoch 44/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.4248 - categorical_accuracy: 0.7850 - val_loss: 0.8177 - val_categorical_accuracy: 0.6800
# Epoch 45/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.4003 - categorical_accuracy: 0.7950 - val_loss: 0.9691 - val_categorical_accuracy: 0.7000
# Epoch 46/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.3606 - categorical_accuracy: 0.8150 - val_loss: 0.9771 - val_categorical_accuracy: 0.7000
# Epoch 47/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.4079 - categorical_accuracy: 0.7800 - val_loss: 1.1755 - val_categorical_accuracy: 0.7000
# Epoch 48/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5323 - categorical_accuracy: 0.7700 - val_loss: 0.8470 - val_categorical_accuracy: 0.6800
# Epoch 49/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.4624 - categorical_accuracy: 0.8350 - val_loss: 0.9197 - val_categorical_accuracy: 0.7200
# Epoch 50/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3660 - categorical_accuracy: 0.8050 - val_loss: 0.7241 - val_categorical_accuracy: 0.7000
# Epoch 51/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3354 - categorical_accuracy: 0.8400 - val_loss: 0.9401 - val_categorical_accuracy: 0.7200
# Epoch 52/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.3291 - categorical_accuracy: 0.8200 - val_loss: 0.8869 - val_categorical_accuracy: 0.7200
# Epoch 53/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3188 - categorical_accuracy: 0.8250 - val_loss: 0.8204 - val_categorical_accuracy: 0.7400
# Epoch 54/100
# 10/10 [==============================] - 1s 67ms/step - loss: 0.3193 - categorical_accuracy: 0.8250 - val_loss: 0.8915 - val_categorical_accuracy: 0.7200
# Epoch 55/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.2923 - categorical_accuracy: 0.8450 - val_loss: 0.8459 - val_categorical_accuracy: 0.7400
# Epoch 56/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.2859 - categorical_accuracy: 0.8500 - val_loss: 0.9126 - val_categorical_accuracy: 0.7200
# Epoch 57/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.6639 - categorical_accuracy: 0.8450 - val_loss: 6.0553 - val_categorical_accuracy: 0.6600
# Epoch 58/100
# 10/10 [==============================] - 1s 73ms/step - loss: 2.1309 - categorical_accuracy: 0.6450 - val_loss: 1.2000 - val_categorical_accuracy: 0.5400
# Epoch 59/100
# 10/10 [==============================] - 1s 76ms/step - loss: 1.0880 - categorical_accuracy: 0.5500 - val_loss: 1.1419 - val_categorical_accuracy: 0.5000
# Epoch 60/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.9621 - categorical_accuracy: 0.5600 - val_loss: 1.0083 - val_categorical_accuracy: 0.5200
# Epoch 61/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.8345 - categorical_accuracy: 0.5300 - val_loss: 0.9442 - val_categorical_accuracy: 0.5200
# Epoch 62/100
# 10/10 [==============================] - 1s 71ms/step - loss: 1.1900 - categorical_accuracy: 0.4650 - val_loss: 0.9980 - val_categorical_accuracy: 0.6000
# Epoch 63/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.8928 - categorical_accuracy: 0.6450 - val_loss: 0.8459 - val_categorical_accuracy: 0.6800
# Epoch 64/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.7278 - categorical_accuracy: 0.6300 - val_loss: 0.7037 - val_categorical_accuracy: 0.6400
# Epoch 65/100
# 10/10 [==============================] - 1s 115ms/step - loss: 0.5891 - categorical_accuracy: 0.6750 - val_loss: 0.5983 - val_categorical_accuracy: 0.7400
# Epoch 66/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5047 - categorical_accuracy: 0.7450 - val_loss: 0.5758 - val_categorical_accuracy: 0.7600
# Epoch 67/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.5167 - categorical_accuracy: 0.7450 - val_loss: 0.6679 - val_categorical_accuracy: 0.6600
# Epoch 68/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.5044 - categorical_accuracy: 0.7450 - val_loss: 0.5951 - val_categorical_accuracy: 0.7200
# Epoch 69/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.5106 - categorical_accuracy: 0.7200 - val_loss: 0.5744 - val_categorical_accuracy: 0.7600
# Epoch 70/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4841 - categorical_accuracy: 0.7600 - val_loss: 0.5707 - val_categorical_accuracy: 0.6800
# Epoch 71/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4594 - categorical_accuracy: 0.8050 - val_loss: 0.5788 - val_categorical_accuracy: 0.7000
# Epoch 72/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.4423 - categorical_accuracy: 0.7850 - val_loss: 0.5199 - val_categorical_accuracy: 0.7600
# Epoch 73/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.3890 - categorical_accuracy: 0.7500 - val_loss: 0.6116 - val_categorical_accuracy: 0.6800
# Epoch 74/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.3713 - categorical_accuracy: 0.8200 - val_loss: 0.5529 - val_categorical_accuracy: 0.7200
# Epoch 75/100
# 10/10 [==============================] - 1s 67ms/step - loss: 0.3835 - categorical_accuracy: 0.8100 - val_loss: 0.6954 - val_categorical_accuracy: 0.6800
# Epoch 76/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.3296 - categorical_accuracy: 0.8200 - val_loss: 0.6730 - val_categorical_accuracy: 0.6800
# Epoch 77/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.3612 - categorical_accuracy: 0.8200 - val_loss: 0.6513 - val_categorical_accuracy: 0.7400
# Epoch 78/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.3587 - categorical_accuracy: 0.7900 - val_loss: 0.5236 - val_categorical_accuracy: 0.7600
# Epoch 79/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.3458 - categorical_accuracy: 0.8250 - val_loss: 0.5680 - val_categorical_accuracy: 0.7400
# Epoch 80/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.3635 - categorical_accuracy: 0.7550 - val_loss: 0.5871 - val_categorical_accuracy: 0.7400
# Epoch 81/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3768 - categorical_accuracy: 0.8000 - val_loss: 0.5804 - val_categorical_accuracy: 0.7600
# Epoch 82/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.3280 - categorical_accuracy: 0.8150 - val_loss: 0.5869 - val_categorical_accuracy: 0.7600
# Epoch 83/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.3127 - categorical_accuracy: 0.8150 - val_loss: 0.5758 - val_categorical_accuracy: 0.7200
# Epoch 84/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.2873 - categorical_accuracy: 0.8400 - val_loss: 0.7880 - val_categorical_accuracy: 0.7400
# Epoch 85/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.3322 - categorical_accuracy: 0.8600 - val_loss: 0.6089 - val_categorical_accuracy: 0.7400
# Epoch 86/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.3364 - categorical_accuracy: 0.8400 - val_loss: 0.5661 - val_categorical_accuracy: 0.7400
# Epoch 87/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.3070 - categorical_accuracy: 0.8350 - val_loss: 0.5153 - val_categorical_accuracy: 0.7400
# Epoch 88/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.3072 - categorical_accuracy: 0.8400 - val_loss: 0.6537 - val_categorical_accuracy: 0.7400
# Epoch 89/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.2976 - categorical_accuracy: 0.8250 - val_loss: 0.6112 - val_categorical_accuracy: 0.7600
# Epoch 90/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.3770 - categorical_accuracy: 0.8000 - val_loss: 0.5103 - val_categorical_accuracy: 0.7400
# Epoch 91/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.3248 - categorical_accuracy: 0.8650 - val_loss: 0.5700 - val_categorical_accuracy: 0.7800
# Epoch 92/100
# 10/10 [==============================] - 1s 70ms/step - loss: 0.3051 - categorical_accuracy: 0.8250 - val_loss: 0.5787 - val_categorical_accuracy: 0.7400
# Epoch 93/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.2880 - categorical_accuracy: 0.8700 - val_loss: 0.5711 - val_categorical_accuracy: 0.7400
# Epoch 94/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.2826 - categorical_accuracy: 0.8350 - val_loss: 0.6712 - val_categorical_accuracy: 0.7800
# Epoch 95/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.2805 - categorical_accuracy: 0.8500 - val_loss: 0.6445 - val_categorical_accuracy: 0.7000
# Epoch 96/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.2917 - categorical_accuracy: 0.8550 - val_loss: 0.6907 - val_categorical_accuracy: 0.7600
# Epoch 97/100
# 10/10 [==============================] - 1s 69ms/step - loss: 0.2917 - categorical_accuracy: 0.8350 - val_loss: 0.8173 - val_categorical_accuracy: 0.7200
# Epoch 98/100
# 10/10 [==============================] - 1s 72ms/step - loss: 0.3202 - categorical_accuracy: 0.8250 - val_loss: 0.6285 - val_categorical_accuracy: 0.7800
# Epoch 99/100
# 10/10 [==============================] - 1s 71ms/step - loss: 0.3096 - categorical_accuracy: 0.8250 - val_loss: 0.5743 - val_categorical_accuracy: 0.7600
# Epoch 100/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.2981 - categorical_accuracy: 0.7850 - val_loss: 0.5415 - val_categorical_accuracy: 0.7800
# TRAINING TIME:  93.99435043334961

# %%
print(history.history.keys())

plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
print()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %%
model.save("/content/drive/MyDrive/VietNam SignLanguage/LSTM-Mediapipe_NoAug.keras")

# %% [markdown]
# # Đánh giá trên tập đánh giá

# %%
from sklearn.metrics import classification_report

# %%
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Sử dụng axis=1 thay vì axis=3
y_true_classes = np.argmax(y_test_decode, axis=1)  # Sử dụng axis=0 để chuyển đổi thành dạng số lớp

print(classification_report(y_true_classes, y_pred_classes))
# Out:
# 2/2 [==============================] - 2s 45ms/step
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        10
#            1       1.00      0.90      0.95        10
#            2       0.90      0.90      0.90        10
#            3       0.91      1.00      0.95        10
#            4       0.55      0.60      0.57        10
#
#     accuracy                           0.78        50
#    macro avg       0.78      0.78      0.78        50
# weighted avg       0.78      0.78      0.78        50
