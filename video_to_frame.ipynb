# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os
from os.path import join, exists

# %%
def resizeScale(img, scale = 30):
  scale_percent = scale # percent of original size
  width = int(img.shape[1] * scale_percent / 100)
  height = int(img.shape[0] * scale_percent / 100)
  dim = (width, height)

  # resize image
  resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
  return resized

# %%
def videotoframe(input_path, output_path, numframe=5, start=0, stop=0, typefolder=''):

    print(input_path)
    print(output_path)

    if typefolder != '':
        input_path = os.path.join(input_path, typefolder)
        output_path = os.path.join(output_path, typefolder)

    # make sure output folder exists
    if not exists(output_path):
        os.makedirs(output_path)

    os.chdir(input_path)

    words = os.listdir(os.getcwd())
    for word in words:
        word_path = os.path.join(input_path, word)
        output_word_path = os.path.join(output_path, word)

        if not exists(output_word_path):
            os.makedirs(output_word_path)

        os.chdir(word_path)

        videos = os.listdir(os.getcwd())
        videos = [video for video in videos if(os.path.isfile(video))]

        for video in videos:
            # Playing video from file:
            video_path = os.path.abspath(video)
            # print(video_path)
            cap = cv2.VideoCapture(video_path)
            length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            currentFrame = -1
            skipframe = int((length - start - stop)/numframe)
            takeframe = skipframe + start
            taken = 0
            print('video',video,'length', length, 'skip', skipframe)

            output_video_path = os.path.join(output_word_path, video)
            if not exists(output_video_path):
                os.makedirs(output_video_path)

            while(True):
                # Capture frame-by-frame
                ret, frame = cap.read()
                currentFrame += 1

                if ret == False:
                    break

                if currentFrame < takeframe:
                    continue

                if taken >= numframe:
                    break

                # Saves image of the current frame in jpg file
                name = output_video_path + '/' + \
                    os.path.basename(video_path).split(
                        '.')[0] + '_frame_' + str(currentFrame) + '.jpeg'
                # print ('Creating ' + name)
                frame = resizeScale(frame)
                cv2.imwrite(name, frame)

                takeframe += skipframe
                taken += 1

            # When everything done, release the capture
            cap.release()
            cv2.destroyAllWindows()

# %%
import zipfile

# Đường dẫn tới file zip đã được tải lên
zip_file_path = '/content/drive/MyDrive/VietNam SignLanguage/lsa64_raw.zip'

# Đường dẫn đến thư mục bạn muốn giải nén vào
extract_dir = '/content/drive/MyDrive/VietNam SignLanguage/Data/validation_dir'

# Giải nén file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# %%
# os.chdir('/content/drive/MyDrive/VSLProject/Datasets')
input_path = '/content/drive/MyDrive/VietNam SignLanguage/Data'
output_path = '/content/drive/MyDrive/VietNam SignLanguage/videoperfolder'

# videotoframe(input_path, output_path,10,10,30,'test')
videotoframe(input_path=input_path,output_path=output_path,numframe=10, start=10,stop=30,typefolder='validation_dir')
# Out:
# /content/drive/MyDrive/VietNam SignLanguage/Data
# /content/drive/MyDrive/VietNam SignLanguage/videoperfolder
# video 001_001_001.mp4 length 88 skip 4
# video 001_001_002.mp4 length 148 skip 10
# video 001_001_003.mp4 length 118 skip 7
# video 001_001_004.mp4 length 118 skip 7
# video 001_001_005.mp4 length 88 skip 4
# video 001_002_001.mp4 length 118 skip 7
# video 001_002_002.mp4 length 118 skip 7
# video 001_002_003.mp4 length 118 skip 7
# video 001_002_004.mp4 length 118 skip 7
# video 001_002_005.mp4 length 118 skip 7
# video 001_003_001.mp4 length 118 skip 7
# video 001_003_002.mp4 length 118 skip 7
# video 001_003_003.mp4 length 118 skip 7
# video 001_003_004.mp4 length 118 skip 7
# video 001_003_005.mp4 length 118 skip 7
# video 001_004_001.mp4 length 148 skip 10
# video 001_004_002.mp4 length 148 skip 10
# video 001_004_003.mp4 length 148 skip 10
# video 001_004_004.mp4 length 148 skip 10
# video 001_004_005.mp4 length 118 skip 7
# video 001_005_001.mp4 length 118 skip 7
# video 001_005_002.mp4 length 118 skip 7
# video 001_005_003.mp4 length 118 skip 7
# video 001_005_004.mp4 length 148 skip 10
# video 001_005_005.mp4 length 118 skip 7
# video 001_006_001.mp4 length 118 skip 7
# video 001_006_002.mp4 length 118 skip 7
# video 001_006_003.mp4 length 118 skip 7
# video 001_006_004.mp4 length 118 skip 7
# video 001_006_005.mp4 length 148 skip 10
# video 001_007_001.mp4 length 88 skip 4
# video 001_007_002.mp4 length 88 skip 4
# video 001_007_003.mp4 length 148 skip 10
# video 001_007_004.mp4 length 148 skip 10
# video 001_007_005.mp4 length 88 skip 4
# video 001_008_001.mp4 length 88 skip 4
# video 001_008_002.mp4 length 88 skip 4
# video 001_008_003.mp4 length 88 skip 4
# video 001_008_004.mp4 length 118 skip 7
# video 001_008_005.mp4 length 88 skip 4
# video 001_009_001.mp4 length 178 skip 13
# video 001_009_002.mp4 length 118 skip 7
# video 001_009_003.mp4 length 88 skip 4
# video 001_009_004.mp4 length 88 skip 4
# video 001_009_005.mp4 length 118 skip 7
# video 001_010_001.mp4 length 148 skip 10
# video 001_010_002.mp4 length 118 skip 7
# video 001_010_003.mp4 length 118 skip 7
# video 001_010_004.mp4 length 88 skip 4
# video 001_010_005.mp4 length 118 skip 7
# video 002_001_001.mp4 length 118 skip 7
# video 002_001_002.mp4 length 118 skip 7
# video 002_001_003.mp4 length 118 skip 7
# video 002_001_004.mp4 length 118 skip 7
# video 002_001_005.mp4 length 118 skip 7
# video 002_002_001.mp4 length 118 skip 7
# video 002_002_002.mp4 length 118 skip 7
# video 002_002_003.mp4 length 118 skip 7
# video 002_002_004.mp4 length 118 skip 7
# video 002_002_005.mp4 length 118 skip 7
# video 002_003_001.mp4 length 118 skip 7
# video 002_003_002.mp4 length 118 skip 7
# video 002_003_003.mp4 length 118 skip 7
# video 002_003_004.mp4 length 118 skip 7
# video 002_003_005.mp4 length 118 skip 7
# video 002_004_001.mp4 length 148 skip 10
# video 002_004_002.mp4 length 118 skip 7
# video 002_004_003.mp4 length 148 skip 10
# video 002_004_004.mp4 length 118 skip 7
# video 002_004_005.mp4 length 148 skip 10
# video 002_005_001.mp4 length 118 skip 7
# video 002_005_002.mp4 length 148 skip 10
# video 002_005_003.mp4 length 118 skip 7
# video 002_005_004.mp4 length 118 skip 7
# video 002_005_005.mp4 length 118 skip 7
# video 002_006_001.mp4 length 148 skip 10
# video 002_006_002.mp4 length 118 skip 7
# video 002_006_003.mp4 length 118 skip 7
# video 002_006_004.mp4 length 148 skip 10
# video 002_006_005.mp4 length 148 skip 10
# video 002_007_001.mp4 length 118 skip 7
# video 002_007_002.mp4 length 88 skip 4
# video 002_007_003.mp4 length 118 skip 7
# video 002_007_004.mp4 length 88 skip 4
# video 002_007_005.mp4 length 118 skip 7
# video 002_008_001.mp4 length 118 skip 7
# video 002_008_002.mp4 length 118 skip 7
# video 002_008_003.mp4 length 118 skip 7
# video 002_008_004.mp4 length 148 skip 10
# video 002_008_005.mp4 length 118 skip 7
# video 002_009_001.mp4 length 118 skip 7
# video 002_009_002.mp4 length 118 skip 7
# video 002_009_003.mp4 length 148 skip 10
# video 002_009_004.mp4 length 118 skip 7
# video 002_009_005.mp4 length 148 skip 10
# video 002_010_001.mp4 length 148 skip 10
# video 002_010_002.mp4 length 148 skip 10
# video 002_010_003.mp4 length 118 skip 7
# video 002_010_004.mp4 length 118 skip 7
# video 002_010_005.mp4 length 88 skip 4
# video 003_001_001.mp4 length 118 skip 7
# video 003_001_002.mp4 length 118 skip 7
# video 003_001_003.mp4 length 118 skip 7
# video 003_001_004.mp4 length 118 skip 7
# video 003_001_005.mp4 length 118 skip 7
# video 003_002_001.mp4 length 118 skip 7
# video 003_002_002.mp4 length 118 skip 7
# video 003_002_003.mp4 length 118 skip 7
# video 003_002_004.mp4 length 148 skip 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7a5440b345f6> in <cell line: 6>()
#       4
#       5 # videotoframe(input_path, output_path,10,10,30,'test')
# ----> 6 videotoframe(input_path=input_path,output_path=output_path,numframe=10, start=10,stop=30,typefolder='validation_dir')
#
# <ipython-input-4-d6f6fec98561> in videotoframe(input_path, output_path, numframe, start, stop, typefolder)
#      64                 # print ('Creating ' + name)
#      65                 frame = resizeScale(frame)
# ---> 66                 cv2.imwrite(name, frame)
#      67
#      68                 takeframe += skipframe
#
# KeyboardInterrupt:

# %%
# videotoframe(input_path, output_path,10,10,30,'test_dir')
# Out:
# /content/drive/MyDrive/VietNam SignLanguage/train_test
# /content/drive/MyDrive/VietNam SignLanguage/videoperfolder
# video Xanhla_011_001.mp4 length 50 skip 1
# video Xanhla_011_005.mp4 length 59 skip 1
# video Xanhla_011_010.mp4 length 29 skip -1
# video Xanhla_011_009.mp4 length 30 skip -1
# video Xanhla_011_008.mp4 length 34 skip 0
# video Xanhla_011_007.mp4 length 28 skip -1
# video Xanhla_011_006.mp4 length 33 skip 0
# video Xanhla_011_004.mp4 length 50 skip 1
# video Xanhla_011_003.mp4 length 44 skip 0
# video Xanhla_011_002.mp4 length 45 skip 0
# video Do_011_010.mp4 length 45 skip 0
# video Do_011_009.mp4 length 53 skip 1
# video Do_011_008.mp4 length 54 skip 1
# video Do_011_007.mp4 length 40 skip 0
# video Do_011_006.mp4 length 30 skip -1
# video Do_011_005.mp4 length 27 skip -1
# video Do_011_004.mp4 length 28 skip -1
# video Do_011_003.mp4 length 43 skip 0
# video Do_011_002.mp4 length 40 skip 0
# video Do_011_001.mp4 length 43 skip 0
# video Hong_011_010.mp4 length 24 skip -1
# video Hong_011_009.mp4 length 27 skip -1
# video Hong_011_008.mp4 length 16 skip -2
# video Hong_011_007.mp4 length 18 skip -2
# video Hong_011_006.mp4 length 20 skip -2
# video Hong_011_005.mp4 length 17 skip -2
# video Hong_011_004.mp4 length 24 skip -1
# video Hong_011_003.mp4 length 34 skip 0
# video Hong_011_002.mp4 length 20 skip -2
# video Hong_011_001.mp4 length 18 skip -2
# video Vang_011_010.mp4 length 16 skip -2
# video Vang_011_009.mp4 length 20 skip -2
# video Vang_011_008.mp4 length 17 skip -2
# video Vang_011_007.mp4 length 20 skip -2
# video Vang_011_006.mp4 length 17 skip -2
# video Vang_011_005.mp4 length 19 skip -2
# video Vang_011_004.mp4 length 22 skip -1
# video Vang_011_003.mp4 length 22 skip -1
# video Vang_011_002.mp4 length 22 skip -1
# video Vang_011_001.mp4 length 21 skip -1
# video Xanhduong_011_010.mp4 length 88 skip 4
# video Xanhduong_011_009.mp4 length 74 skip 3
# video Xanhduong_011_008.mp4 length 82 skip 4
# video Xanhduong_011_007.mp4 length 70 skip 3
# video Xanhduong_011_006.mp4 length 75 skip 3
# video Xanhduong_011_005.mp4 length 72 skip 3
# video Xanhduong_011_004.mp4 length 61 skip 2
# video Xanhduong_011_003.mp4 length 77 skip 3
# video Xanhduong_011_002.mp4 length 79 skip 3
# video Xanhduong_011_001.mp4 length 74 skip 3

# %%
# create csv
import csv
os.chdir('/content/drive/MyDrive/VietNam SignLanguage/')
path = 'videoperfolder'
# path = 'splits/'
def createCSV(path,setd):
  with open(path+'/'+setd +'.csv', mode='w') as filecsv:
    writer = csv.writer(filecsv)
    path1 = os.path.join(path,setd)
    listword = os.listdir(path1)
    for word in listword:
      word_path = os.path.join(path1, word)
      videos = os.listdir(word_path)
      print(word)
      for video in videos:
        if setd == 'train_dir_2':
        # if setd == 'test_dir':
            video_path = word + '/' + video
            writer.writerow([video_path])
  print ('Done ####################################################')
  # if setd == 'train_dir_2':
  #   with open(path+'/val_new.csv', mode='w') as valcsv:
  #     writer = csv.writer(valcsv)
  #     path2 = os.path.join(path,setd)
  #     listword = os.listdir(path2)
  #     for word in listword:
  #       word_path = os.path.join(path2, word)
  #       videos = os.listdir(word_path)
  #       print(word)
  #       for video in videos:
  #         video_path = word + '/' + video
  #         writer.writerow([video_path])
  #   print('Done')

# createCSV(path,'test_dir')
createCSV(path,'train_dir')
# Out:
# Xanh la
# Do
# Hong
# Vang
# Xanh duong
# Done ####################################################

# %%
createCSV(path,'test_dir')
# Out:
# Xanh la
# Do
# Hong
# Vang
# Xanh duong
# Done ####################################################

# %%
# os.chdir('/content/drive/MyDrive/VSLProject/Datasets')
input_path = '/content/drive/MyDrive/VietNam SignLanguage/Data'
output_path = '/content/drive/MyDrive/VietNam SignLanguage/Data_Frame'

# videotoframe(input_path, output_path,10,10,30,'test')
videotoframe(input_path=input_path,output_path=output_path,numframe=10, start=10,stop=30,typefolder='train_dir')
# Out:
# /content/drive/MyDrive/VietNam SignLanguage/Data
# /content/drive/MyDrive/VietNam SignLanguage/Data_Frame
# video Do_001_001.mp4 length 65 skip 2
# video Do_001_002.mp4 length 60 skip 2
# video Do_001_003.mp4 length 61 skip 2
# video Do_001_005.mp4 length 63 skip 2
# video Do_001_004.mp4 length 71 skip 3
# video Do_002_001.mp4 length 69 skip 2
# video Do_002_004.mp4 length 65 skip 2
# video Do_002_002.mp4 length 75 skip 3
# video Do_002_003.mp4 length 71 skip 3
# video Do_003_001.mp4 length 64 skip 2
# video Do_002_005.mp4 length 71 skip 3
# video Do_003_002.mp4 length 62 skip 2
# video Do_003_004.mp4 length 70 skip 3
# video Do_003_005.mp4 length 66 skip 2
# video Do_004_001.mp4 length 98 skip 5
# video Do_004_002.mp4 length 75 skip 3
# video Do_004_003.mp4 length 123 skip 8
# video Do_004_005.mp4 length 89 skip 4
# video Do_004_004.mp4 length 68 skip 2
# video Do_005_001.mp4 length 82 skip 4
# video Do_005_002.mp4 length 96 skip 5
# video Do_003_003.mp4 length 63 skip 2
# video Do_005_003.mp4 length 73 skip 3
# video Do_005_004.mp4 length 59 skip 1
# video Do_005_005.mp4 length 66 skip 2
# video Do_006_002.mp4 length 76 skip 3
# video Do_006_001.mp4 length 91 skip 5
# video Do_006_004.mp4 length 96 skip 5
# video Do_006_003.mp4 length 71 skip 3
# video Do_006_005.mp4 length 106 skip 6
# video Do_007_002.mp4 length 58 skip 1
# video Do_007_001.mp4 length 78 skip 3
# video Do_007_003.mp4 length 76 skip 3
# video Do_008_001.mp4 length 77 skip 3
# video Do_007_004.mp4 length 59 skip 1
# video Do_007_005.mp4 length 74 skip 3
# video Do_008_005.mp4 length 76 skip 3
# video Do_008_002.mp4 length 72 skip 3
# video Do_008_003.mp4 length 80 skip 4
# video Do_008_004.mp4 length 114 skip 7
# video Do_009_001.mp4 length 72 skip 3
# video Do_009_003.mp4 length 93 skip 5
# video Do_009_002.mp4 length 64 skip 2
# video Do_009_004.mp4 length 88 skip 4
# video Do_009_005.mp4 length 91 skip 5
# video Do_010_001.mp4 length 110 skip 7
# video Do_010_004.mp4 length 77 skip 3
# video Do_010_003.mp4 length 98 skip 5
# video Do_010_005.mp4 length 54 skip 1
# video Do_010_002.mp4 length 115 skip 7
# video Hong_001_001.mp4 length 45 skip 0
# video Hong_001_002.mp4 length 45 skip 0
# video Hong_001_004.mp4 length 50 skip 1
# video Hong_001_005.mp4 length 67 skip 2
# video Hong_001_003.mp4 length 62 skip 2
# video Hong_002_001.mp4 length 85 skip 4
# video Hong_002_003.mp4 length 71 skip 3
# video Hong_002_002.mp4 length 38 skip 0
# video Hong_002_005.mp4 length 47 skip 0
# video Hong_002_004.mp4 length 72 skip 3
# video Hong_003_001.mp4 length 43 skip 0
# video Hong_003_003.mp4 length 50 skip 1
# video Hong_003_004.mp4 length 72 skip 3
# video Hong_003_002.mp4 length 44 skip 0
# video Hong_003_005.mp4 length 65 skip 2
# video Hong_004_001.mp4 length 58 skip 1
# video Hong_004_002.mp4 length 45 skip 0
# video Hong_004_004.mp4 length 45 skip 0
# video Hong_004_003.mp4 length 52 skip 1
# video Hong_004_005.mp4 length 51 skip 1
# video Hong_005_001.mp4 length 54 skip 1
# video Hong_005_002.mp4 length 53 skip 1
# video Hong_005_003.mp4 length 65 skip 2
# video Hong_006_002.mp4 length 68 skip 2
# video Hong_006_001.mp4 length 48 skip 0
# video Hong_006_003.mp4 length 62 skip 2
# video Hong_005_004.mp4 length 57 skip 1
# video Hong_005_005.mp4 length 68 skip 2
# video Hong_007_001.mp4 length 43 skip 0
# video Hong_006_005.mp4 length 71 skip 3
# video Hong_006_004.mp4 length 38 skip 0
# video Hong_007_002.mp4 length 25 skip -1
# video Hong_007_003.mp4 length 46 skip 0
# video Hong_008_001.mp4 length 43 skip 0
# video Hong_007_005.mp4 length 35 skip 0
# video Hong_007_004.mp4 length 48 skip 0
# video Hong_008_002.mp4 length 36 skip 0
# video Hong_008_004.mp4 length 57 skip 1
# video Hong_008_003.mp4 length 41 skip 0
# video Hong_009_003.mp4 length 46 skip 0
# video Hong_009_002.mp4 length 32 skip 0
# video Hong_008_005.mp4 length 52 skip 1
# video Hong_009_004.mp4 length 36 skip 0
# video Hong_009_001.mp4 length 32 skip 0
# video Hong_010_002.mp4 length 65 skip 2
# video Hong_010_001.mp4 length 56 skip 1
# video Hong_009_005.mp4 length 32 skip 0
# video Hong_010_003.mp4 length 76 skip 3
# video Hong_010_005.mp4 length 66 skip 2
# video Hong_010_004.mp4 length 59 skip 1
# video Vang_001_001.mp4 length 53 skip 1
# video Vang_001_003.mp4 length 46 skip 0
# video Vang_001_004.mp4 length 41 skip 0
# video Vang_001_002.mp4 length 39 skip 0
# video Vang_001_005.mp4 length 56 skip 1
# video Vang_002_002.mp4 length 93 skip 5
# video Vang_002_003.mp4 length 61 skip 2
# video Vang_002_001.mp4 length 101 skip 6
# video Vang_002_004.mp4 length 44 skip 0
# video Vang_003_001.mp4 length 42 skip 0
# video Vang_002_005.mp4 length 45 skip 0
# video Vang_003_002.mp4 length 41 skip 0
# video Vang_003_003.mp4 length 45 skip 0
# video Vang_003_005.mp4 length 64 skip 2
# video Vang_004_001.mp4 length 50 skip 1
# video Vang_003_004.mp4 length 45 skip 0
# video Vang_004_003.mp4 length 66 skip 2
# video Vang_004_005.mp4 length 62 skip 2
# video Vang_005_001.mp4 length 48 skip 0
# video Vang_005_002.mp4 length 64 skip 2
# video Vang_005_004.mp4 length 58 skip 1
# video Vang_005_005.mp4 length 58 skip 1
# video Vang_006_002.mp4 length 79 skip 3
# video Vang_006_001.mp4 length 66 skip 2
# video Vang_004_004.mp4 length 72 skip 3
# video Vang_004_002.mp4 length 50 skip 1
# video Vang_006_003.mp4 length 69 skip 2
# video Vang_006_005.mp4 length 61 skip 2
# video Vang_007_002.mp4 length 45 skip 0
# video Vang_007_001.mp4 length 50 skip 1
# video Vang_006_004.mp4 length 70 skip 3
# video Vang_007_004.mp4 length 70 skip 3
# video Vang_007_003.mp4 length 46 skip 0
# video Vang_007_005.mp4 length 42 skip 0
# video Vang_008_001.mp4 length 46 skip 0
# video Vang_008_003.mp4 length 44 skip 0
# video Vang_008_002.mp4 length 42 skip 0
# video Vang_008_004.mp4 length 70 skip 3
# video Vang_008_005.mp4 length 49 skip 0
# video Vang_009_001.mp4 length 68 skip 2
# video Vang_009_002.mp4 length 43 skip 0
# video Vang_009_003.mp4 length 41 skip 0
# video Vang_009_004.mp4 length 45 skip 0
# video Vang_010_001.mp4 length 43 skip 0
# video Vang_009_005.mp4 length 41 skip 0
# video Vang_010_002.mp4 length 50 skip 1
# video Vang_005_003.mp4 length 57 skip 1
# video Vang_010_003.mp4 length 52 skip 1
# video Vang_010_004.mp4 length 56 skip 1
# video Vang_010_005.mp4 length 57 skip 1
# video Xanhduong_001_001.mp4 length 105 skip 6
# video Xanhduong_001_003.mp4 length 103 skip 6
# video Xanhduong_001_002.mp4 length 106 skip 6
# video Xanhduong_001_004.mp4 length 92 skip 5
# video Xanhduong_002_002.mp4 length 98 skip 5
# video Xanhduong_001_005.mp4 length 101 skip 6
# video Xanhduong_002_003.mp4 length 95 skip 5
# video Xanhduong_002_004.mp4 length 111 skip 7
# video Xanhduong_002_005.mp4 length 101 skip 6
# video Xanhduong_003_001.mp4 length 109 skip 6
# video Xanhduong_002_001.mp4 length 107 skip 6
# video Xanhduong_003_002.mp4 length 132 skip 9
# video Xanhduong_003_003.mp4 length 108 skip 6
# video Xanhduong_003_004.mp4 length 80 skip 4
# video Xanhduong_003_005.mp4 length 119 skip 7
# video Xanhduong_004_001.mp4 length 129 skip 8
# video Xanhduong_004_002.mp4 length 124 skip 8
# video Xanhduong_004_003.mp4 length 135 skip 9
# video Xanhduong_005_001.mp4 length 127 skip 8
# video Xanhduong_004_005.mp4 length 124 skip 8
# video Xanhduong_004_004.mp4 length 111 skip 7
# video Xanhduong_005_002.mp4 length 141 skip 10
# video Xanhduong_005_003.mp4 length 132 skip 9
# video Xanhduong_005_004.mp4 length 110 skip 7
# video Xanhduong_005_005.mp4 length 110 skip 7
# video Xanhduong_006_001.mp4 length 105 skip 6
# video Xanhduong_006_003.mp4 length 105 skip 6
# video Xanhduong_006_002.mp4 length 121 skip 8
# video Xanhduong_006_004.mp4 length 105 skip 6
# video Xanhduong_006_005.mp4 length 157 skip 11
# video Xanhduong_007_002.mp4 length 102 skip 6
# video Xanhduong_007_001.mp4 length 108 skip 6
# video Xanhduong_007_003.mp4 length 103 skip 6
# video Xanhduong_007_004.mp4 length 109 skip 6
# video Xanhduong_008_001.mp4 length 200 skip 16
# video Xanhduong_008_002.mp4 length 135 skip 9
# video Xanhduong_008_003.mp4 length 107 skip 6
# video Xanhduong_008_004.mp4 length 143 skip 10
# video Xanhduong_007_005.mp4 length 96 skip 5
# video Xanhduong_008_005.mp4 length 134 skip 9
# video Xanhduong_009_001.mp4 length 105 skip 6
# video Xanhduong_009_002.mp4 length 109 skip 6
# video Xanhduong_009_003.mp4 length 102 skip 6
# video Xanhduong_009_004.mp4 length 75 skip 3
# video Xanhduong_009_005.mp4 length 113 skip 7
# video Xanhduong_010_001.mp4 length 107 skip 6
# video Xanhduong_010_002.mp4 length 104 skip 6
# video Xanhduong_010_003.mp4 length 108 skip 6
# video Xanhduong_010_004.mp4 length 84 skip 4
# video Xanhduong_010_005.mp4 length 82 skip 4
# video Xanhla_001_002.mp4 length 62 skip 2
# video Xanhla_001_003.mp4 length 67 skip 2
# video Xanhla_001_005.mp4 length 66 skip 2
# video Xanhla_001_001.mp4 length 61 skip 2
# video Xanhla_001_004.mp4 length 72 skip 3
# video Xanhla_002_001.mp4 length 70 skip 3
# video Xanhla_002_002.mp4 length 71 skip 3
# video Xanhla_002_004.mp4 length 102 skip 6
# video Xanhla_002_005.mp4 length 75 skip 3
# video Xanhla_003_002.mp4 length 70 skip 3
# video Xanhla_003_003.mp4 length 90 skip 5
# video Xanhla_003_005.mp4 length 66 skip 2
# video Xanhla_003_004.mp4 length 72 skip 3
# video Xanhla_004_001.mp4 length 69 skip 2
# video Xanhla_004_002.mp4 length 74 skip 3
# video Xanhla_005_001.mp4 length 71 skip 3
# video Xanhla_004_004.mp4 length 66 skip 2
# video Xanhla_004_003.mp4 length 81 skip 4
# video Xanhla_005_002.mp4 length 87 skip 4
# video Xanhla_002_003.mp4 length 73 skip 3
# video Xanhla_003_001.mp4 length 79 skip 3
# video Xanhla_005_003.mp4 length 68 skip 2
# video Xanhla_005_004.mp4 length 77 skip 3
# video Xanhla_005_005.mp4 length 71 skip 3
# video Xanhla_006_002.mp4 length 101 skip 6
# video Xanhla_006_001.mp4 length 79 skip 3
# video Xanhla_006_003.mp4 length 99 skip 5
# video Xanhla_006_004.mp4 length 98 skip 5
# video Xanhla_006_005.mp4 length 97 skip 5
# video Xanhla_007_001.mp4 length 60 skip 2
# video Xanhla_004_005.mp4 length 58 skip 1
# video Xanhla_007_002.mp4 length 63 skip 2
# video Xanhla_007_003.mp4 length 52 skip 1
# video Xanhla_007_005.mp4 length 66 skip 2
# video Xanhla_008_001.mp4 length 60 skip 2
# video Xanhla_008_002.mp4 length 66 skip 2
# video Xanhla_008_003.mp4 length 66 skip 2
# video Xanhla_009_001.mp4 length 73 skip 3
# video Xanhla_009_002.mp4 length 70 skip 3
# video Xanhla_007_004.mp4 length 55 skip 1
# video Xanhla_009_004.mp4 length 65 skip 2
# video Xanhla_009_005.mp4 length 66 skip 2
# video Xanhla_010_002.mp4 length 51 skip 1
# video Xanhla_010_001.mp4 length 75 skip 3
# video Xanhla_008_004.mp4 length 61 skip 2
# video Xanhla_008_005.mp4 length 76 skip 3
# video Xanhla_010_003.mp4 length 49 skip 0
# video Xanhla_010_004.mp4 length 77 skip 3
# video Xanhla_010_005.mp4 length 88 skip 4
# video Xanhla_009_003.mp4 length 66 skip 2

# %%
path = '/content/drive/MyDrive/VietNam SignLanguage/Data_Frame'
def createCSV(path,setd):
  with open(path+'/'+setd +'_origin.csv', mode='w') as filecsv:
    writer = csv.writer(filecsv)
    path1 = os.path.join(path,setd)
    listword = os.listdir(path1)
    for word in listword:
      word_path = os.path.join(path1, word)
      videos = os.listdir(word_path)
      print(word)
      for video in videos:
        if setd == 'train_dir':
        # if setd == 'test_dir':
            video_path = word + '/' + video
            writer.writerow([video_path])
  print ('Done ####################################################')
createCSV(path,'train_dir')
# Out:
# Do
# Hong
# Vang
# Xanh duong
# Xanh la
# Done ####################################################

# %%
# os.chdir('/content/drive/MyDrive/VSLProject/Datasets')
def videotoframe(input_path, output_path, numframe=5, start=0, stop=0):
    # Make sure output folder exists
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # Playing video from file
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        print("Error opening video stream or file")
        return

    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    currentFrame = -1
    skipframe = int((length - start - stop) / numframe)
    takeframe = skipframe + start
    taken = 0
    print('video', input_path, 'length', length, 'skip', skipframe)

    output_video_path = os.path.join(output_path, os.path.basename(input_path).split('.')[0])
    if not os.path.exists(output_video_path):
        os.makedirs(output_video_path)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        currentFrame += 1

        if not ret:
            break

        if currentFrame < takeframe:
            continue

        if taken >= numframe:
            break

        # Save image of the current frame in jpg file
        name = os.path.join(output_video_path, os.path.basename(input_path).split('.')[0] + '_frame_' + str(currentFrame) + '.jpeg')
        frame = resizeScale(frame)
        cv2.imwrite(name, frame)

        takeframe += skipframe
        taken += 1

    # When everything done, release the capture
    cap.release()
    cv2.destroyAllWindows()
input_path = '/content/drive/MyDrive/VietNam SignLanguage/Data_Aug/train_dir/Hong/Hong_005_003_5.mp4'
output_path = '/content/drive/MyDrive/VietNam SignLanguage/TempOutput/train_dir'

# videotoframe(input_path, output_path,10,10,30,'test')
videotoframe(input_path=input_path,output_path=output_path,numframe=10, start=10,stop=30)
# Out:
# video /content/drive/MyDrive/VietNam SignLanguage/Data_Aug/train_dir/Hong/Hong_005_003_5.mp4 length 65 skip 2
